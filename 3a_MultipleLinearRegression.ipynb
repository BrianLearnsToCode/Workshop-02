# %% [markdown]
# <img src="images/Picture0.png" width=200x />
#
# # Notebook 03a -Multiple Linear Regression
#
# ## Instructions
# ...
#
# ## Pre-requisites
# ...
#
# ## Credits
# ...

# %% [markdown]
# ## If you are using Colab, save a copy of this notebook!!
#
# Before we get started, it is crucially important that you **save a copy of the notebook** to a local folder if you are accessing this notebook in Google Colab! Please go to:
#
# ```
# File -> Make a copy
# ```

# %%
#@title (Hidden) Diagnostic Check
import os
import sys
import pandas as pd
import numpy as np
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# This notebook follows along with the notes found [here](https://drive.google.com/file/d/1NfyR93g1tKQbsVt6kri9C8tlrn3DwQil/view?usp=sharing).

# %%
data = pd.read_csv("https://raw.githubusercontent.com/akmand/datasets/master/openintro/evals.csv")
display(data)
# Out:
#      score          rank     ethnicity  gender     language  age  \
# 0      4.7  tenure track      minority  female      english   36
# 1      4.1  tenure track      minority  female      english   36
# 2      3.9  tenure track      minority  female      english   36
# 3      4.8  tenure track      minority  female      english   36
# 4      4.6       tenured  not minority    male      english   59
# ..     ...           ...           ...     ...          ...  ...
# 458    4.5  tenure track  not minority    male      english   32
# 459    3.5  tenure track      minority  female  non-english   42
# 460    4.4  tenure track      minority  female  non-english   42
# 461    4.4  tenure track      minority  female  non-english   42
# 462    4.1  tenure track      minority  female  non-english   42
#
#      cls_perc_eval  cls_did_eval  cls_students cls_level  ...   cls_credits  \
# 0         55.81395            24            43     upper  ...  multi credit
# 1         68.80000            86           125     upper  ...  multi credit
# 2         60.80000            76           125     upper  ...  multi credit
# 3         62.60163            77           123     upper  ...  multi credit
# 4         85.00000            17            20     upper  ...  multi credit
# ..             ...           ...           ...       ...  ...           ...
# 458       60.46511            52            86     upper  ...  multi credit
# 459       57.14286            48            84     upper  ...  multi credit
# 460       77.61194            52            67     upper  ...  multi credit
# 461       81.81818            54            66     upper  ...  multi credit
# 462       80.00000            28            35     lower  ...    one credit
#
#     bty_f1lower  bty_f1upper  bty_f2upper  bty_m1lower  bty_m1upper  \
# 0             5            7            6            2            4
# 1             5            7            6            2            4
# 2             5            7            6            2            4
# 3             5            7            6            2            4
# 4             4            4            2            2            3
# ..          ...          ...          ...          ...          ...
# 458           6            6            9            7            8
# 459           3            8            7            4            6
# 460           3            8            7            4            6
# 461           3            8            7            4            6
# 462           3            8            7            4            6
#
#      bty_m2upper  bty_avg  pic_outfit pic_color
# 0              6    5.000  not formal     color
# 1              6    5.000  not formal     color
# 2              6    5.000  not formal     color
# 3              6    5.000  not formal     color
# 4              3    3.000  not formal     color
# ..           ...      ...         ...       ...
# 458            5    6.833  not formal     color
# 459            4    5.333  not formal     color
# 460            4    5.333  not formal     color
# 461            4    5.333  not formal     color
# 462            4    5.333  not formal     color
#
# [463 rows x 21 columns]

# %% [markdown]
# ## Course Evaluation Dataset
#
# This data is part of the [OpenIntro resources](https://www.openintro.org/book/statdata/?data=evals).
#
# "The data are gathered from end of semester student evaluations for a large sample of professors from the University of Texas at Austin. In addition, six students rate the professors' physical appearance. The result is a data frame where each row contains a different course and each column has information on either the course or the professor."
#
# ####Variables
# - score: Average professor evaluation score: (1) very unsatisfactory - (5) excellent.
# - rank: Rank of professor: teaching, tenure track, tenured.
# - ethnicity: Ethnicity of professor: not minority, minority.
# - gender: Gender of professor: female, male.
# - language: Language of school where professor received education: English or non-English.
# - age: Age of professor.
# - cls_perc_eval: Percent of students in class who completed evaluation.
# - cls_did_eval: Number of students in class who completed evaluation.
# - cls_students: Total number of students in class.
# - cls_level: Class level: lower, upper.
# - cls_profs: Number of professors teaching sections in course in sample: single, multiple.
# - cls_credits: Number of credits of class: one credit (lab, PE, etc.), multi credit.
# - bty_f1lower: Beauty rating of professor from lower level female: (1) lowest - (10) highest.
# - bty_f1upper: Beauty rating of professor from upper level female: (1) lowest - (10) highest.
# - bty_f2upper: Beauty rating of professor from second level female: (1) lowest - (10) highest.
# - bty_m1lower: Beauty rating of professor from lower level male: (1) lowest - (10) highest.
# - bty_m1upper: Beauty rating of professor from upper level male: (1) lowest - (10) highest.
# - bty_m2upper: Beauty rating of professor from second upper level male: (1) lowest - (10) highest.
# - bty_avg: Average beauty rating of professor.
# - pic_outfit: Outfit of professor in picture: not formal, formal.
# - pic_color: Color of professor’s picture: color, black & white.

# %% [markdown]
# ### Is there a difference in the mean course evaluation score between female and male instructors?

# %%
sns.boxplot(data = data,
            x="gender",
            y="score")
#sns.pairplot(data); ## this will take awhile
# Out:
# <AxesSubplot: xlabel='gender', ylabel='score'>

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ### Is there a statistically significant linear relationship between the beauty score and the course evaluation score?

# %%
sns.scatterplot(data=data,  x="bty_avg", y="score");

# %% [markdown]
# Fit a linear regression model and make a conclusion. Don't forget to check the conditions! (Slide 8, page 4 of Simple Linear Regression Notes)

# %%
model_formulation = smf.ols('score ~ bty_avg', data = data)
results = model_formulation.fit()
results.params
# Out:
# Intercept    3.880338
# bty_avg      0.066637
# dtype: float64

# %% [markdown]
# # Multiple Regression with Binary Categorical Variable

# %% [markdown]
# ### Is there a difference in the mean course evalution score between female and male instructors after accounting for the beauty score?

# %%
sns.scatterplot(data=data,  x="bty_avg", y="score", hue = 'gender');

# %%
# Specify the model
model_formulation = smf.ols("score ~ bty_avg + gender", data = data)

# Fit the model
results = model_formulation.fit()

# View parameters
results.params
# Out:
# Intercept         3.747338
# gender[T.male]    0.172390
# bty_avg           0.074155
# dtype: float64

# %% [markdown]
# ## Parallel Slopes Model Summary
#
# Which coefficient should we do inference on to answer our question of interest?

# %%
model_summary = results.summary()
print(model_summary)

model_anova = statsmodels.stats.anova.anova_lm(results)
print(model_anova)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Sat, 04 Nov 2023   Prob (F-statistic):           8.18e-07
# Time:                        14:46:34   Log-Likelihood:                -360.37
# No. Observations:                 463   AIC:                             726.7
# Df Residuals:                     460   BIC:                             739.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.7473      0.085     44.266      0.000       3.581       3.914
# gender[T.male]     0.1724      0.050      3.433      0.001       0.074       0.271
# bty_avg            0.0742      0.016      4.563      0.000       0.042       0.106
# ==============================================================================
# Omnibus:                       30.145   Durbin-Watson:                   1.277
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.960
# Skew:                          -0.672   Prob(JB):                     2.56e-08
# Kurtosis:                       2.925   Cond. No.                         17.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#              df      sum_sq   mean_sq          F    PR(>F)
# gender      1.0    2.260213  2.260213   8.086320  0.004659
# bty_avg     1.0    5.819173  5.819173  20.819135  0.000006
# Residual  460.0  128.574955  0.279511        NaN       NaN

# %% [markdown]
# ### Parallel Slopes Predicted Values

# %%
# Retrieve beta estimates from statsmodels
beta_hat = results.params

# split into groups
males = data[data.gender == "male"]
#males.info()

females = data[data.gender == "female"]
#females.info()

# Compute estimates
Y_hat_M = beta_hat[0] + beta_hat[1] + males.bty_avg*beta_hat[2]
Y_hat_F = beta_hat[0] + females.bty_avg*beta_hat[2]

# %%
males['predVal'] = Y_hat_M
females['predVal'] = Y_hat_F
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\3808106815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   males['predVal'] = Y_hat_M
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\3808106815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   females['predVal'] = Y_hat_F

# %%
# Show data points
sns.scatterplot(data=data,  x="bty_avg", y="score", hue = 'gender');
# Graph the line of best fit
sns.lineplot(data = males, x="bty_avg", y='predVal', color='orange')
sns.lineplot(data = females, x="bty_avg", y='predVal', color='blue')
# Out:
# <AxesSubplot: xlabel='bty_avg', ylabel='score'>

# %% [markdown]
# ### Parallel Slopes Residuals
#
# We still can't forget to check the residuals. What condition does the following code chunk assess? Do you believe the condition is met?

# %%
#residuals = results.resid
#data['resid'] = residuals
#plot = sns.scatterplot(data=data,  x="bty_avg", y="resid", hue = 'gender');

residuals  =results.resid
beta_hat = results.params
Y_hat = beta_hat[0] + data.bty_avg*beta_hat[1]
plt.scatter(Y_hat, residuals)
plt.axhline(y = 0, color = 'r', linestyle = '-')
plt.xlabel('fitted $y$')
plt.ylabel('Residuals')
plt.title("Comparing residuals against covariate")
plt.show()

# %% [markdown]
# What condition does the following code chunk assess? Do you believe the condition is met?

# %%
results.resid.mean()
# Out:
# -3.1719287623631903e-15

# %% [markdown]
# What condition does the following code chunk assess? Do you believe the condition is met?

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.distplot(residuals, fit=stats.norm, ax=ax1)
ax1.set_title('Distribution of Residuals')
ax1.set_xlabel('Residual')
ax1.set_ylabel('Probability')
_ = stats.probplot(residuals.ravel(), plot=ax2)
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\2369400450.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, fit=stats.norm, ax=ax1)

# %% [markdown]
# ### Is the relationship between beauty score and course evaluation score the same for female and male instructors?

# %%
# Specify the model
model_formulation = smf.ols("score ~ bty_avg * gender", data = data)

# Fit the model
results = model_formulation.fit()

# View parameters
results.params
# Out:
# Intercept                 3.950060
# gender[T.male]           -0.183509
# bty_avg                   0.030643
# bty_avg:gender[T.male]    0.079619
# dtype: float64

# %% [markdown]
# ### Interaction Model Summary
#
# Which coefficient should we do inference on to answer our question of interest?

# %%
model_summary = results.summary()
print(model_summary)

model_anova = statsmodels.stats.anova.anova_lm(results)
print(model_anova)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     11.74
# Date:                Sat, 04 Nov 2023   Prob (F-statistic):           2.00e-07
# Time:                        14:53:49   Log-Likelihood:                -357.35
# No. Observations:                 463   AIC:                             722.7
# Df Residuals:                     459   BIC:                             739.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  3.9501      0.118     33.475      0.000       3.718       4.182
# gender[T.male]            -0.1835      0.153     -1.196      0.232      -0.485       0.118
# bty_avg                    0.0306      0.024      1.277      0.202      -0.017       0.078
# bty_avg:gender[T.male]     0.0796      0.032      2.452      0.015       0.016       0.143
# ==============================================================================
# Omnibus:                       26.631   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.276
# Skew:                          -0.624   Prob(JB):                     2.67e-07
# Kurtosis:                       2.890   Cond. No.                         42.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                    df      sum_sq   mean_sq          F    PR(>F)
# gender            1.0    2.260213  2.260213   8.174440  0.004442
# bty_avg           1.0    5.819173  5.819173  21.046010  0.000006
# bty_avg:gender    1.0    1.662530  1.662530   6.012817  0.014574
# Residual        459.0  126.912425  0.276498        NaN       NaN

# %% [markdown]
# ### Interaction Predicted Values

# %%
# Retrieve beta estimates from statsmodels
beta_hat = results.params


# Compute estimates
Y_hat_M2 = beta_hat[0] + beta_hat[1] + males.bty_avg*(beta_hat[2] + beta_hat[3])
Y_hat_F2 = beta_hat[0] + females.bty_avg*beta_hat[2]

males['predVal2'] = Y_hat_M2
females['predVal2'] = Y_hat_F2
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\3985048391.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   males['predVal2'] = Y_hat_M2
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\3985048391.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   females['predVal2'] = Y_hat_F2

# %%
# Show data points
sns.scatterplot(data=data,  x="bty_avg", y="score", hue = 'gender');
# Graph the line of best fit
sns.lineplot(data = males, x="bty_avg", y='predVal2', color='blue')
sns.lineplot(data = females, x="bty_avg", y='predVal2', color='orange')
# Out:
# <AxesSubplot: xlabel='bty_avg', ylabel='score'>

# %% [markdown]
# ### Interaction Residuals
#
# Are the conditions for inference met?

# %%
residuals = results.resid

data['resid'] = residuals

plot = sns.scatterplot(data=data,  x="bty_avg", y="resid", hue = 'gender');
plot.axhline(y=0, color = 'black')

results.resid.mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.distplot(residuals, fit=stats.norm, ax=ax1)
ax1.set_title('Distribution of Residuals')
ax1.set_xlabel('Residual')
ax1.set_ylabel('Probability')
_ = stats.probplot(residuals.ravel(), plot=ax2)
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\2945360582.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, fit=stats.norm, ax=ax1)

# %% [markdown]
# # Multiple Regression with Categorical Variable with more than two levels

# %%
sns.scatterplot(data=data,  x="bty_avg", y="score", hue = 'rank');

# %% [markdown]
# What statistical question can we ask using the variables displayed here?

# %%
# Specify the model
model_formulation = smf.ols("score ~ bty_avg * rank", data = data)

# Fit the model
results = model_formulation.fit()

# View parameters
results.params
# Out:
# Intercept                       4.098110
# rank[T.tenure track]           -0.018847
# rank[T.tenured]                -0.409105
# bty_avg                         0.041713
# bty_avg:rank[T.tenure track]   -0.026399
# bty_avg:rank[T.tenured]         0.065859
# dtype: float64

# %% [markdown]
# What do you conclude about your question of interest?

# %%
model_summary = results.summary()
print(model_summary)

model_anova = statsmodels.stats.anova.anova_lm(results)
print(model_anova)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     5.701
# Date:                Sat, 04 Nov 2023   Prob (F-statistic):           4.09e-05
# Time:                        16:21:40   Log-Likelihood:                -360.47
# No. Observations:                 463   AIC:                             732.9
# Df Residuals:                     457   BIC:                             757.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        4.0981      0.150     27.395      0.000       3.804       4.392
# rank[T.tenure track]            -0.0188      0.230     -0.082      0.935      -0.472       0.434
# rank[T.tenured]                 -0.4091      0.182     -2.246      0.025      -0.767      -0.051
# bty_avg                          0.0417      0.031      1.329      0.184      -0.020       0.103
# bty_avg:rank[T.tenure track]    -0.0264      0.046     -0.570      0.569      -0.117       0.065
# bty_avg:rank[T.tenured]          0.0659      0.039      1.679      0.094      -0.011       0.143
# ==============================================================================
# Omnibus:                       28.497   Durbin-Watson:                   1.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.579
# Skew:                          -0.643   Prob(JB):                     8.42e-08
# Kurtosis:                       2.811   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                  df      sum_sq   mean_sq          F    PR(>F)
# rank            2.0    1.589145  0.794573   2.822953  0.060467
# bty_avg         1.0    4.767929  4.767929  16.939471  0.000046
# bty_avg:rank    2.0    1.666119  0.833059   2.959689  0.052830
# Residual      457.0  128.631148  0.281469        NaN       NaN

# %%
# Retrieve beta estimates from statsmodels
beta_hat = results.params

# split into groups
#tt = data[data.rank == 'tenure track']
tt = data.loc[data['rank'] == 'tenure track']

tn = data.loc[data['rank'] == "tenured"]

te = data.loc[data['rank'] == "teaching"]


# Compute estimates
Y_hat_TT = beta_hat[0] + beta_hat[1] + tt.bty_avg*(beta_hat[3] + beta_hat[4])
Y_hat_TN = beta_hat[0] + beta_hat[2] + tn.bty_avg*(beta_hat[3] + beta_hat[5])
Y_hat_TE = beta_hat[0] + te.bty_avg*beta_hat[3]

tt['predVal'] = Y_hat_TT
tn['predVal'] = Y_hat_TN
te['predVal'] = Y_hat_TE
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\1416910315.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['predVal'] = Y_hat_TT
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\1416910315.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn['predVal'] = Y_hat_TN
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\1416910315.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['predVal'] = Y_hat_TE

# %%
# Show data points
sns.scatterplot(data=data,  x="bty_avg", y="score", hue = 'rank');
# Graph the line of best fit
sns.lineplot(data = tt, x="bty_avg", y='predVal', color='blue')
sns.lineplot(data = tn, x="bty_avg", y='predVal', color='orange')
sns.lineplot(data = te, x="bty_avg", y='predVal', color='green')
# Out:
# <AxesSubplot: xlabel='bty_avg', ylabel='score'>

# %%
residuals = results.resid

data['resid'] = residuals

plot = sns.scatterplot(data=data,  x="bty_avg", y="resid", hue = 'rank');
plot.axhline(y=0, color = 'black')

results.resid.mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.distplot(residuals, fit=stats.norm, ax=ax1)
ax1.set_title('Distribution of Residuals')
ax1.set_xlabel('Residual')
ax1.set_ylabel('Probability')
_ = stats.probplot(residuals.ravel(), plot=ax2)
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\3371393648.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, fit=stats.norm, ax=ax1)

# %% [markdown]
# # Multiple Regression with Multiple Quantitative Variables

# %% [markdown]
# ### Is there a statistically significant linear relationship between the beauty score and the course evaluation score after accounting for instructor age?

# %%
sns.scatterplot(data=data,  x="bty_avg", y="score");

# %%
sns.scatterplot(data=data,  x="age", y="score");

# %%
sns.scatterplot(data=data,  x="age", y="bty_avg");

# %% [markdown]
# ## Check your understanding
#
#  Consider all of the models presented so far. What are the different elements of statistical output that can be used as evidence that the model is ``good"? Which do you find most convincing? Why?

# %% [markdown]
# ### Multicollinearity
#
# Do we need to worry about age and bty_avg being redundant (i.e. explain similar variability in score)?
#
# We can compute a variance inflation factor:
#
# $$VIF = \frac{1}{1-R^2}$$
#
# Where R^2 is the R^2 we have seen before in a regression model of one covariate against another.
#
# A rule of thumb is an acceptable VIF is < 5.

# %%
model_formulation = smf.ols("bty_avg ~ age", data = data)
model_summary = results.summary()
display(model_summary)

vif = 1/(1-0.038**2)
vif
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     9.031
# Date:                Sat, 04 Nov 2023   Prob (F-statistic):           0.000142
# Time:                        15:50:09   Log-Likelihood:                -365.56
# No. Observations:                 463   AIC:                             737.1
# Df Residuals:                     460   BIC:                             749.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.0547      0.170     23.870      0.000       3.721       4.389
# bty_avg        0.0607      0.017      3.548      0.000       0.027       0.094
# age           -0.0031      0.003     -1.148      0.251      -0.008       0.002
# ==============================================================================
# Omnibus:                       32.361   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.864
# Skew:                          -0.700   Prob(JB):                     6.00e-09
# Kurtosis:                       3.021   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# 1.0014460881512905

# %%
# Specify the model
model_formulation = smf.ols("score ~ bty_avg + age", data = data)

# Fit the model
results = model_formulation.fit()

# View parameters
results.params
# Out:
# Intercept    4.054732
# bty_avg      0.060656
# age         -0.003059
# dtype: float64

# %%
model_summary = results.summary()
display(model_summary)

model_anova = statsmodels.stats.anova.anova_lm(results)
display(model_anova)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     9.031
# Date:                Sat, 04 Nov 2023   Prob (F-statistic):           0.000142
# Time:                        15:50:26   Log-Likelihood:                -365.56
# No. Observations:                 463   AIC:                             737.1
# Df Residuals:                     460   BIC:                             749.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.0547      0.170     23.870      0.000       3.721       4.389
# bty_avg        0.0607      0.017      3.548      0.000       0.027       0.094
# age           -0.0031      0.003     -1.148      0.251      -0.008       0.002
# ==============================================================================
# Omnibus:                       32.361   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.864
# Skew:                          -0.700   Prob(JB):                     6.00e-09
# Kurtosis:                       3.021   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
#              df      sum_sq   mean_sq          F    PR(>F)
# bty_avg     1.0    4.785944  4.785944  16.742800  0.000051
# age         1.0    0.376994  0.376994   1.318849  0.251396
# Residual  460.0  131.491403  0.285851        NaN       NaN

# %%
residuals = results.resid

data['resid'] = residuals

predVal = results.params[0] + results.params[1]*data.bty_avg + results.params[2]*data.age

data['predVal'] = predVal

plot = sns.scatterplot(data=data,  x="predVal", y="resid");
plot.axhline(y=0, color = 'black')

results.resid.mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.distplot(residuals, fit=stats.norm, ax=ax1)
ax1.set_title('Distribution of Residuals')
ax1.set_xlabel('Residual')
ax1.set_ylabel('Probability')
_ = stats.probplot(residuals.ravel(), plot=ax2)
# Out:
# C:\Users\bingy\AppData\Local\Temp\ipykernel_24752\1060337983.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, fit=stats.norm, ax=ax1)
